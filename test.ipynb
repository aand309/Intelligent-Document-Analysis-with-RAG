# %%
#inport librarys
import openai
import langchain
import pinecone
from langchain.document_loaders import PyPDFDirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import Pinecone
from langchain.llms import OpenAI
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 4
#       2 import openai
#       3 import langchain
# ----> 4 import pinecone
#       5 from langchain.document_loaders import PyPDFDirectoryLoader
#       6 from langchain.text_splitter import RecursiveCharacterTextSplitter
#
# File c:\Users\anand\OneDrive\Desktop\Rag applicatin\venv\lib\site-packages\pinecone\__init__.py:5
#       1 """
#       2 .. include:: ../README.md
#       3 """
# ----> 5 raise Exception(
#       6     "The official Pinecone python package has been renamed from `pinecone-client` to `pinecone`. Please remove `pinecone-client` from your project dependencies and add `pinecone` instead. See the README at https://github.com/pinecone-io/pinecone-python-client for more information on using the python SDK."
#       7 )
#
# ...

# %%
from dotenv import load_dotenv
load_dotenv()
import os

# %%
#from langchain_community.document_loaders import PyPDFLoader

def read_single_pdf(file_path):
    loader = PyPDFDirectoryLoader(file_path)
    documents = loader.load()
    return documents

# %%
doc=read_single_pdf('documents/')
len(doc)
# Out:
# 5

# %%
#dividing the documents into chunks
def chunk_dat(docs,chunk_size=1000, chunk_overlap=200):
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size, chunk_overlap=chunk_overlap
    )
    texts = text_splitter.split_documents(docs)
    return texts

# %%
documents=chunk_dat(docs=doc)
documents
# Out:
# [Document(metadata={'producer': 'Microsoft® Word 2016; modified using iText® 7.1.12 ©2000-2020 iText Group NV (AGPL-version); modified using iText® Core 7.2.4 (AGPL version) ©2000-2022 iText Group NV', 'creator': 'Microsoft® Word 2016', 'creationdate': '2025-08-05T18:52:02+08:00', 'moddate': '2025-09-03T13:25:33-04:00', 'ieee article id': '11151165', 'ieee issue id': '6423298', 'subject': 'IEEE Journal of the Electron Devices Society; ;PP;99;10.1109/JEDS.2025.3604839', 'ieee publication id': '6245494', 'title': 'Accelerated Atomistic Modeling of Phase Change Memory Using Deep Neural Network and Specialized Hardware', 'source': 'documents\\Accelerated_Atomistic_Modeling_of_Phase_Change_Memory_Using_Deep_Neural_Network_and_Specialized_Hardwa.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1'}, page_content='Zhuoying Zhao et al.: Efficient and Accurate Atomistic Modeling of Phase Change Memory 1 \n  \nAbstract—Atomistic simulations offer valuable insights \ninto phase change memory (P
# ...

# %%
#embedding the documents and storing in vector database
embeddings = OpenAIEmbeddings(openai_api_key=os.getenv("OPENAI_API_KEY"))
embeddings
# Out:
# OpenAIEmbeddings(client=<openai.resources.embeddings.Embeddings object at 0x000001DCAE490BE0>, async_client=<openai.resources.embeddings.AsyncEmbeddings object at 0x000001DCAD7C65F0>, model='text-embedding-ada-002', deployment='text-embedding-ada-002', openai_api_version='', openai_api_base=None, openai_api_type='', openai_proxy='', embedding_ctx_length=8191, openai_api_key='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', openai_organization=None, allowed_special=set(), disallowed_special='all', chunk_size=1000, max_retries=2, request_timeout=None, headers=None, tiktoken_enabled=True, tiktoken_model_name=None, show_progress_bar=False, model_kwargs={}, skip_empty=False, default_headers=None, default_query=None, retry_min_seconds=4, retry_max_seconds=20, http_client=None)

# %%
import pinecone
print(pinecone.__version__)
print(dir(pinecone))
# Out:
# 7.3.0
# ...

# %%
 #vector search db in pinecone 
from pinecone import Pinecone

# Initialize client
import os
os.environ["PINECONE_API_KEY"] = "pcsk_2ds8Sr_UscPHeBpGgKertmRyDM1p28TXAKWSPP4Lwu27m2zT5vEMcM8qL4itb8qcYwYBoX"

client = Pinecone(api_key=os.environ["PINECONE_API_KEY"], environment="us-east-1")

# Use client to interact with the index
index_name = "langchainvector"
#index = client.index(index_name)

# Now you can use `index` to query, upsert vectors etc.

# %%
# Ensure pinecone-client is up to date
# %pip install --upgrade "pinecone-client>=3.0.0"

# Use the Pinecone class from langchain.vectorstores (already imported in cell 9)
index = LangChainPinecone.from_documents(documents, embeddings, index_name=index_name)
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[96], line 5
#       2 get_ipython().run_line_magic('pip', 'install --upgrade "pinecone-client>=3.0.0"')
#       4 # Use the Pinecone class from langchain.vectorstores (already imported in cell 9)
# ----> 5 index = LangChainPinecone.from_documents(documents, embeddings, index_name=index_name)
#
# File c:\Users\anand\OneDrive\Desktop\Rag applicatin\venv\lib\site-packages\langchain_core\vectorstores\base.py:848, in VectorStore.from_documents(cls, documents, embedding, **kwargs)
#     845     if any(ids):
#     846         kwargs["ids"] = ids
# --> 848 return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#
# ...
